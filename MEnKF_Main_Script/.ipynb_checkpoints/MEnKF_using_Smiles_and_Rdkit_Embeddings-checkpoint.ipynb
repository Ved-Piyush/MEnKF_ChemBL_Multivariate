# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import KFold
from sklearn.feature_selection import VarianceThreshold
import random
import pickle
from sklearn.preprocessing import StandardScaler
import os
import tensorflow as tf
from tqdm.notebook import tqdm
from scipy.stats import multivariate_normal as mvn
import matplotlib.pyplot as plt
from scipy.linalg import block_diag
# Out:
# 2023-08-01 18:06:56.946196: I tensorflow/core/util/port.cc:110] oneDNN custom operations are on. You may see slightly different numerical results due to floating-point round-off errors from different computation orders. To turn them off, set the environment variable `TF_ENABLE_ONEDNN_OPTS=0`.
# 2023-08-01 18:06:56.948770: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-01 18:06:56.989191: I tensorflow/tsl/cuda/cudart_stub.cc:28] Could not find cuda drivers on your machine, GPU will not be used.
# 2023-08-01 18:06:56.989939: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 AVX512F AVX512_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# 2023-08-01 18:06:57.762392: W tensorflow/compiler/tf2tensorrt/utils/py_utils.cc:38] TF-TRT Warning: Could not find TensorRT

# %%
def get_targets_with_weights(batch_data, initial_ensembles, size_ens, ann): 
    
    target_dim = 1
    
    weights_ann_1 = ann.get_weights()
    
    h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
def ann(hidden = 32, input_shape = 256, output_shape = 1): 
    input_layer = tf.keras.layers.Input(shape = (input_shape))
    hidden_layer = tf.keras.layers.Dense(hidden)
    hidden_output = hidden_layer(input_layer)
    pred_layer = tf.keras.layers.Dense(output_shape, activation = "relu")
    pred_output = pred_layer(hidden_output)
#     pred_output = tf.keras.layers.Activation("softmax")(pred_output)
    model = tf.keras.models.Model(input_layer, pred_output)
    return model

# %%
def generate_initial_ensembles(num_weights, lambda1, size_ens):
    mean_vec = np.zeros((num_weights,))
    cov_matrix = lambda1*np.identity(num_weights)
    mvn_samp = mvn(mean_vec, cov_matrix)
    return mvn_samp.rvs(size_ens)

# %%
def expit(x):
    """Compute softmax values for each sets of scores in x."""
#     e_x = np.exp(x - np.max(x))
    return 1 / (1 + np.exp(-x))

# %%
hidden_neurons = 16

# %%
def get_initial_X_t(data1, data2, size_ens, var_weights = 0.1):
    samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    
    initial_ensembles1 = generate_initial_ensembles(samp_ann.count_params(), var_weights, size_ens)
    data1_out1, data1_stack1 = get_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens, ann = samp_ann)
    
    initial_ensembles2 = generate_initial_ensembles(samp_ann.count_params(), var_weights, size_ens)
    data1_out2, data1_stack2 = get_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens, ann = samp_ann)
    
    initial_ensembles3 = generate_initial_ensembles(samp_ann.count_params(), var_weights, size_ens)
    data2_out1, data2_stack1 = get_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens, ann = samp_ann)
    
    initial_ensembles4 = generate_initial_ensembles(samp_ann.count_params(), var_weights, size_ens)
    data2_out2, data2_stack2 = get_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens, ann = samp_ann)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles_for_weights = generate_initial_ensembles(4, var_weights, size_ens)
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = generate_initial_ensembles(4, var_weights, size_ens)
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)    
    
    initial_ensembles_for_D1 = generate_initial_ensembles(1, var_weights, size_ens).reshape(-1,1)
    initial_ensembles_for_D2 = generate_initial_ensembles(1, var_weights, size_ens).reshape(-1,1)
    
    initial_ensembles_for_D1_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    initial_ensembles_for_D2_zero = np.zeros((size_ens,1,1)).reshape(-1,1)
    
    initial_ensembles_for_D = np.concatenate((np.expand_dims(initial_ensembles_for_D1,1),
                                                       np.expand_dims(initial_ensembles_for_D1_zero,1), 
                                                      np.expand_dims(initial_ensembles_for_D2,1),
                                                       np.expand_dims(initial_ensembles_for_D2_zero,1)), axis = 2)
    
    # print(X_t.shape, initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4))
    
    return X_t, initial_ensembles, initial_ensembles_for_weights[:,0,:], initial_ensembles_for_L[:,0,:], initial_ensembles_for_D[:,0,:]

# %%
def get_weighted_targets_with_weights(batch_data, initial_ensembles, size_ens, ann, weights): 
    
    target_dim = 1
    
    weights_ann_1 = ann.get_weights()
    
    h1  = ann.layers[1].output.shape[-1]

    n_hidden_1 = len(weights_ann_1[0].ravel())
    
    hidden_weights_1 = initial_ensembles[:,:n_hidden_1].reshape( size_ens, batch_data.shape[1], h1)
    
    
    hidden_output_1 = np.einsum('ij,kjl->kil', batch_data, hidden_weights_1)

    
    hidden_layer_bias_1 = initial_ensembles[:,n_hidden_1:(n_hidden_1 + h1)].reshape(size_ens, 1,  h1)


    hidden_output_1 = hidden_output_1 + hidden_layer_bias_1

    n_pred_weights_1 = len(weights_ann_1[2].ravel())

    output_weights_1 = initial_ensembles[:,(n_hidden_1 + h1):(n_hidden_1 + h1 + n_pred_weights_1) ].reshape(size_ens, h1, target_dim)


    output_1 = np.einsum('ijk,ikl->ijl', hidden_output_1, output_weights_1)


    output_layer_bias_1 = initial_ensembles[:,(n_hidden_1 + h1 + n_pred_weights_1):(n_hidden_1 + h1 + n_pred_weights_1 + target_dim)].reshape(size_ens, 1, target_dim)


    final_output_1 = output_1 + output_layer_bias_1
    
    final_output_1 = final_output_1[:,:, 0]
    
    final_output_1 = final_output_1*weights
    
    # print(final_output_1.shape, initial_ensembles.shape)
    
    stack = np.hstack((final_output_1, initial_ensembles))

    
    return final_output_1, stack

# %%
alogp_bottleneck = np.load("..//Data/small_mol_phase_3_features_for_both.npy")

# %%
y_valid = pd.read_csv("..//Data/smiles_with_rdkit_with_small_phase_3_outputs.csv")

# %%
std_targets = pickle.load( open('..//Data//target_scaler.pkl', 'rb'))
# Out:
# /home/statgrads/vpiyush2/.conda/envs/enkf/lib/python3.11/site-packages/sklearn/base.py:318: UserWarning: Trying to unpickle estimator StandardScaler from version 1.1.2 when using version 1.2.2. This might lead to breaking code or invalid results. Use at your own risk. For more info please refer to:
# https://scikit-learn.org/stable/model_persistence.html#security-maintainability-limitations
#   warnings.warn(

# %%
y_train = y_valid.values[:,1:]

# %%
y_train = std_targets.transform(y_train)
# Out:
# /home/statgrads/vpiyush2/.conda/envs/enkf/lib/python3.11/site-packages/sklearn/base.py:439: UserWarning: X does not have valid feature names, but StandardScaler was fitted with feature names
#   warnings.warn(

# %%
from sklearn.model_selection import train_test_split

# %%
x_train, x_valid, y_train, y_valid = train_test_split(alogp_bottleneck, y_train, test_size = 0.25, shuffle = True, 
                                                     random_state = 42)

# %%
x_train.shape
# Out:
# (719, 64)

# %%
smiles_feats_train = x_train[:, :32]

# %%
rdkit_feats_train = x_train[:, 32:]

# %%
smiles_feats_valid = x_valid[:, :32]
rdkit_feats_valid = x_valid[:, 32:]

# %%
# size_ens = 250

# %%
def forward_operation(data1, data2, combined_ensembles , size_ens ):
    samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)
    params = samp_ann.count_params()
    initial_ensembles1 = combined_ensembles[:, :params]
    initial_ensembles2 = combined_ensembles[:, params:(2*params)]
    initial_ensembles3 = combined_ensembles[:, (2*params):(3*params)]
    initial_ensembles4 = combined_ensembles[:, (3*params):(4*params)]

    
    initial_ensembles_for_weights = combined_ensembles[:, (4*params):(4*params + 4)]
    
    initial_ensembles_for_L = combined_ensembles[:, (4*params + 4):(4*params + 4 + 4)]
    
    initial_ensembles_for_D = combined_ensembles[:,(4*params + 4 + 4):(4*params + 4 + 4 + 4)]
    
    
    softmax_weights = tf.math.softmax(initial_ensembles_for_weights).numpy()
    
    model_1 = softmax_weights[:,:2].sum(1).reshape(-1,1)
    
    model_2 = softmax_weights[:,2:].sum(1).reshape(-1,1)
    
    data1_out1, data1_stack1 = get_weighted_targets_with_weights(data1, initial_ensembles1, size_ens = size_ens,
                                                                 ann = samp_ann, weights=model_1)
    
    data1_out2, data1_stack2 = get_weighted_targets_with_weights(data1, initial_ensembles2, size_ens = size_ens,
                                                                 ann = samp_ann, weights=model_1)
    
    data2_out1, data2_stack1 = get_weighted_targets_with_weights(data2, initial_ensembles3, size_ens = size_ens,
                                                                 ann = samp_ann, weights=model_2)
    
    data2_out2, data2_stack2 = get_weighted_targets_with_weights(data2, initial_ensembles4, size_ens = size_ens,
                                                                 ann = samp_ann, weights=model_2)   
    
    X_t = np.concatenate((np.expand_dims(data1_stack1, -1), np.expand_dims(data1_stack2, -1), 
                         np.expand_dims(data2_stack1, -1), np.expand_dims(data2_stack2, -1)), axis = -1)
    
    initial_ensembles = np.hstack((initial_ensembles1, initial_ensembles2, initial_ensembles3, initial_ensembles4, 
                        initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))
    
    # print(X_t.shape)
    
    initial_ensembles_for_weights = np.expand_dims(initial_ensembles_for_weights,1)
    
    initial_ensembles_for_L = np.expand_dims(initial_ensembles_for_L,1)
    
    initial_ensembles_for_D = np.expand_dims(initial_ensembles_for_D,1)
    
    # print(initial_ensembles_for_weights.shape)
    
    X_t = np.concatenate((X_t, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D), axis = 1)
    
    weighted_alogp = data1_out1 + data2_out1
    
    weighted_psa = data1_out2 + data2_out2
    
    return X_t, initial_ensembles, weighted_alogp, weighted_psa, model_1, model_2

# %%
samp_ann =  ann(hidden = hidden_neurons, input_shape = 32, output_shape = 1)

# %%
total_weights = 4*(samp_ann.count_params() + 1 + 1 + 1)

# %%
total_weights
# Out:
# 2192

# %%
reduction = 8

# %%
size_ens = total_weights//reduction

# %%
size_ens
# Out:
# 274

# %%
X_t, initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens)

# %%
# X_t, initial_ensembles, initial_ensembles_for_weights = get_initial_X_t(smiles_feats_train, rdkit_feats_train, size_ens = size_ens)

# %%
initial_ensembles = np.hstack((initial_ensembles, initial_ensembles_for_weights, initial_ensembles_for_L, initial_ensembles_for_D))

# %%
initial_ensembles.shape
# Out:
# (274, 2192)

# %%
G_t = [[1, 0, 1, 0], [0, 1, 0, 1]]
G_t = np.array(G_t).T

# %%
G_t
# Out:
# array([[1, 0],
#        [0, 1],
#        [1, 0],
#        [0, 1]])

# %%
def get_predictions(data1, data2, initial_ensembles): 
    _,_, weighted_alogp, weighted_psa, w1, w2 = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens)
    weighted_alogp = np.expand_dims(weighted_alogp,-1)
    weighted_psa = np.expand_dims(weighted_psa,-1)
    preds = np.concatenate((weighted_alogp, weighted_psa),-1)
    return preds, w1, w2

# %%
# H_t = np.hstack((np.identity(smiles_feats_train.shape[0]), np.zeros((smiles_feats_train.shape[0], samp_ann.count_params() + 1 + 1 + 1))))

# %%
# H_t.shape

# %%
def calculate_mu_bar_G_bar(data1, data2, initial_ensembles):
    H_t = np.hstack((np.identity(data1.shape[0]), np.zeros((data1.shape[0], samp_ann.count_params() + 1 + 1 + 1))))
    mu_bar = initial_ensembles.mean(0)
    X_t,_, _, _, _, _ = forward_operation(data1, data2, initial_ensembles, size_ens = size_ens)
    X_t = X_t.transpose((0,2,1))
    X_t = X_t.reshape(X_t.shape[0], X_t.shape[1]*X_t.shape[2])
    script_H_t = np.kron(G_t.T, H_t)
    G_u = (script_H_t@X_t.T)
    G_u = G_u.T
    # weighted_alogp = np.expand_dims(weighted_alogp,-1)
    # weighted_psa = np.expand_dims(weighted_psa,-1)
    # G_u = np.concatenate((weighted_alogp, weighted_psa), axis = -1)
    # G_u = G_u.transpose((0,2,1))
    # G_u = G_u.reshape(G_u.shape[0], G_u.shape[1]*G_u.shape[2])
    # G_u
    G_bar = (G_u.mean(0)).ravel()
    return mu_bar.reshape(-1,1), G_bar.reshape(-1,1), G_u

# %%
def calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u): 
    u_j_minus_u_bar = initial_ensembles - mu_bar.reshape(1,-1)
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    c = np.zeros((total_weights, G_bar.shape[0]))
    for i in range(0, size_ens): 
        c += np.kron(u_j_minus_u_bar[i, :].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return c/size_ens, G_u_minus_G_bar

# %%
def calculate_D_u( G_bar, G_u): 
    G_u_minus_G_bar = G_u -  G_bar.reshape(1,-1)
    d = np.zeros((G_bar.shape[0], G_bar.shape[0]))
    for i in range(0, size_ens): 
        d += np.kron(G_u_minus_G_bar[i,:].T.reshape(-1,1), G_u_minus_G_bar[i,:].reshape(-1,1).T)
    return d/size_ens

# %%
# initial_ensembles.shape

# %%
def get_updated_ensemble(data1, data2, initial_ensembles, size_ens = size_ens):
    mu_bar, G_bar, G_u = calculate_mu_bar_G_bar(data1, data2, initial_ensembles)
    C, G_u_minus_G_bar = calculate_C_u(initial_ensembles, mu_bar, G_bar, G_u)
    D = calculate_D_u( G_bar, G_u)
    _, R_t = create_cov(data1.shape[0],initial_ensembles)
    # all_covs = np.array(all_covs)
    D_plus_cov = D + R_t
    D_plus_cov_inv = np.linalg.inv(D_plus_cov)
    mid_quant = C@D_plus_cov_inv
    noise_vec_mean = np.zeros((R_t.shape[0], ))
    noise_mvn = mvn(noise_vec_mean, R_t)
    fudging = noise_mvn.rvs(size_ens)
    interim = (y_train.T.flatten().reshape(1,-1) + fudging)
    right_quant = interim - G_u
    # print(mid_quant.shape, right_quant.shape)
    mid_times_right = mid_quant@right_quant.T
    updated_ensemble = (initial_ensembles + mid_times_right.T)
    return updated_ensemble

# %%
# initial_ensembles[:, -8:-4].mean(0)

# %%
target_dim = 2

# %%
# initial_ensembles[:, -4:]

# %%
# tf.math.softplus(np.array([0.]).reshape(-1,1))

# %%
def create_cov(shape, initial_ensembles):
    cov_part = initial_ensembles[:, -8:-4]
    cov_part = cov_part.mean(0)
    # variances = tf.math.softplus(cov_part[:2]).numpy()
    variances = cov_part[:2]
    covariances = cov_part[2:]
    base_cov = np.identity(target_dim)
    base_cov[0,0] = variances[0]
    base_cov[1,1] = variances[1]
    base_cov[0,1] = covariances[0]
    base_cov[1,0] = covariances[1]
    
    variances1 = tf.math.softplus(initial_ensembles[:, -4:]).numpy()
    variances1 = variances1.mean(0)
    base_variances = np.identity(target_dim)
    base_variances[0,0] = variances1[0]
    base_variances[1,1] = variances1[2]
    
    final = np.linalg.cholesky(base_cov@base_cov.T + base_variances)
    cov_mat = final@final.T
    cov_mat_final = cov_mat
    # cov_mat_final = cov_mat@cov_mat.T
    
    if is_pos_def(cov_mat_final) != True:
        print("resulting cov matrix is not positive semi definite")
        pass
    
    # print(np.linalg.det(cov_mat_final))
    
    var1 = cov_mat_final[0,0]
    var2 = cov_mat_final[1,1]
    cov = cov_mat_final[1,0]

    n = shape
    
    ul = var1*np.identity(n)
    lr = var2*np.identity(n)
    ur = cov*np.identity(n)
    ll = ur.T    
    
    first_row = np.hstack((ul, ur))
    second_row = np.hstack((ll, lr))
    
    R_t = np.vstack((first_row, second_row))
    
    # R_t = block_diag(*([cov_mat_final] * n))
    
    # R_t = np.linalg.inv(R_t)
    
    return cov_mat_final, R_t

# %%
def is_pos_def(x):
    return np.all(np.linalg.eigvals(x) > 0)

# %%
cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

# %%
cov_mat_final
# Out:
# array([[6.96406736e-01, 2.25312475e-04],
#        [2.25312475e-04, 7.00288076e-01]])

# %%
def inverse_transform(data, idx):
    data_cur = data[idx, :, :]
    inv_data_cur = std_targets.inverse_transform(data_cur)
    return inv_data_cur

# %%
from joblib import Parallel, delayed

# %%
from scipy.linalg import norm

# %%
initial_ensembles.shape
# Out:
# (274, 2192)

# %%
# from tqdm.notebook import trange

# %%
# rmse_train

# %%
y_chk_full = pd.read_csv("..//Data/y_train.csv")

# %%
y_chk_full.shape
# Out:
# (1694445, 2)

# %%
np.cov(y_chk_full.values.T)
# Out:
# array([[   3.56194622,  -24.68021802],
#        [ -24.68021802, 1862.41330966]])

# %%
# c = np.zeros((2,2))

# %%
# c = c/size_ens

# %%
# c

# %%
from scipy.stats import pearsonr

# %%
# coverage_train

# %%
# w2 + w1

# %%
# w1

# %%
np.cov(std_targets.inverse_transform(y_train).T)
# Out:
# array([[   7.15535584,  -59.64784375],
#        [ -59.64784375, 3085.51412811]])

# %%
w1_catch = []
w2_catch = []
w1_sd_catch = []
w2_sd_catch = []
weight_norm_mean = []
weight_norm_sd = []

best_rmse = 10000
patience = 0
for i in range(0,10000):
    c = np.zeros((2,2))
    initial_ensembles = get_updated_ensemble(smiles_feats_train, rdkit_feats_train, initial_ensembles)
    G_u_train, w1, w2 = get_predictions(smiles_feats_train, rdkit_feats_train, initial_ensembles)
    
    w1_catch.append(w1.mean())
    w1_sd_catch.append(w1.std())
    
    w2_catch.append(w2.mean())
    w2_sd_catch.append(w2.std())  
    
    print("Epoch " + str(i+1))
    
    
    print("Averaging Weight with SD")
    print([w1.mean(), w1.std()])
    print([w2.mean(), w2.std()])
    
    # G_u_train = get_targets_with_weights(smiles_feats_train, rdkit_feats_train, initial_ensembles, size_ens = size_ens)
    catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_train, i)  for i in range(G_u_train.shape[0]))
    G_u_train = np.array(catch)
    
    y_train_cur = std_targets.inverse_transform(y_train)
    
    li_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[0,:,:]   
    ui_train = np.percentile(G_u_train, axis = 0, q = (2.5, 97.5))[1,:,:]
    
    width_train = ui_train - li_train
    avg_width_train = width_train.mean(0)
    
    ind_train = (y_train_cur >= li_train) & (y_train_cur <= ui_train)
    coverage_train= ind_train.mean(0)
    
    averaged_targets_train = G_u_train.mean(0)
    rmse_train = np.sqrt(((y_train_cur -averaged_targets_train)**2).mean(0))
    # print(rmse_train, coverage_train, avg_width_train)
    pearson_train_alogp = pearsonr(y_train_cur[:,0], averaged_targets_train[:,0])[0]
    pearson_train_psa = pearsonr(y_train_cur[:,1], averaged_targets_train[:,1])[0]
    
    G_u_test, _, _ = get_predictions(smiles_feats_valid, rdkit_feats_valid, initial_ensembles)
    
    catch = Parallel(n_jobs = 15, verbose = 0)(delayed(inverse_transform)(G_u_test, i)  for i in range(G_u_test.shape[0]))
    G_u_test = np.array(catch)
    
    y_valid_cur = std_targets.inverse_transform(y_valid)    
    
    li_test = np.percentile(G_u_test, axis = 0, q = (2.5, 97.5))[0,:,:]   
    ui_test = np.percentile(G_u_test, axis = 0, q = (2.5, 97.5))[1,:,:]
    
    width_test = ui_test - li_test
    avg_width_test = width_test.mean(0)
    
    ind_test = (y_valid_cur >= li_test) & (y_valid_cur <= ui_test)
    coverage_test= ind_test.mean(0)
    
    averaged_targets_test = G_u_test.mean(0)
    rmse_test = np.sqrt(((y_valid_cur -averaged_targets_test)**2).mean(0))    
    
    pearson_test_alogp = pearsonr(y_valid_cur[:,0], averaged_targets_test[:,0])[0]
    pearson_test_psa = pearsonr(y_valid_cur[:,1], averaged_targets_test[:,1])[0]
    
    weight_norms = np.array(norm(initial_ensembles, ord = 2, axis = 1))
    weight_norm_mean.append(weight_norms.mean())
    weight_norm_sd.append(weight_norms.std())
    
   
    print("Weight Norms")
    print([weight_norms.mean(), weight_norms.std()])
    
    
    # if np.mean(coverage_train < 0.95) == 1:
    #     break
        
    cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)
    
    print("standardized_scale_R_t")
    print(np.diag(cov_mat_final), cov_mat_final[0,1])
    
    print("Train RMSEs, Pearson ,Coverages, and Widths")
    print(rmse_train, [pearson_train_alogp, pearson_train_psa] ,coverage_train, avg_width_train)
    
    print("Test RMSEs, Pearson , Coverages, and Widths")
    print(rmse_test, [pearson_test_alogp, pearson_test_psa] , coverage_test, avg_width_test)
    

    
    
    
    value = rmse_train.mean()
    
    for i in range(0, size_ens):
        c+= np.cov(G_u_train[i,:,:].T)
        
    c = c/size_ens    
    
    
    if (value < best_rmse) & (coverage_train.mean() >= 0.95): 
        best_rmse = value
        best_rmse_train = rmse_train
        best_coverage = coverage_train
        best_width = avg_width_train
        patience = 0
        best_rmse_test = rmse_test
        best_coverage_test = coverage_test
        best_width_test = avg_width_test
        best_R_t = c
        best_pearsonr_train = [pearson_train_alogp, pearson_train_psa]
        best_pearsonr_test = [pearson_test_alogp, pearson_test_psa]
        best_initial_ensembles = initial_ensembles
        best_G_u_test = G_u_test
        best_averaged_targets_test = averaged_targets_test
        best_mod1_weight = w1.mean()
        best_mod2_weight = w2.mean()
        best_train_metrics = [best_rmse_train, best_coverage, best_width, best_pearsonr_train]
        best_test_metrics = [best_rmse_test, best_coverage_test, best_width_test, best_pearsonr_test]
        # print(['i', 'best_rmse', 'best_coverage', 'best_rmse_test', 'best_coverage_test', 'best_R_t'])
        # print([i, best_rmse, best_coverage, best_rmse_test, best_coverage_test, best_R_t])
    else:
        patience +=1 
    
    print("data_scale_R_t")
    print(c)
        
    print('patience')
    print(patience)
    
    print("\n")    
    
        
    if patience >= 20:
        break
# Out:
# Epoch 1
# Averaging Weight with SD
# [0.5110686782159961, 0.07501567037575722]
# [0.488931321784004, 0.07501567037575724]
# Weight Norms
# [14.200768792369072, 0.6231892671336083]
# standardized_scale_R_t
# [0.80955323 0.64787903] -0.005595979913658017
# Train RMSEs, Pearson ,Coverages, and Widths
# [ 2.13454712 43.27537571] [0.8813693202204113, 0.7509061828116084] [1. 1.] [ 13.86311055 301.02307795]
# Test RMSEs, Pearson , Coverages, and Widths
# [ 2.06614958 39.56860359] [0.9123594511878591, 0.7510265911297582] [1. 1.] [ 13.63122287 297.54962548]
# data_scale_R_t
# [[ 1.94345336e+01 -8.21328436e+00]
#  [-8.21328436e+00  8.63481906e+03]]
# patience
# 0
#
#
# Epoch 2
# Averaging Weight with SD
# [0.5551558891676969, 0.06808892099224148]
# [0.4448441108323031, 0.06808892099224148]
# Weight Norms
# [14.34038717388011, 0.6625406931563474]
# standardized_scale_R_t
# [0.90212945 0.64357567] 0.001312164643464574
# Train RMSEs, Pearson ,Coverages, and Widths
# [ 1.2252287  38.86574031] [0.9565415332916045, 0.7260188693931371] [1.         0.99721836] [  8.61179339 200.42751528]
# Test RMSEs, Pearson , Coverages, and Widths
# [ 1.21125213 34.28951061] [0.9540701563926803, 0.7393598737030813] [1. 1.] [  8.4685359 198.7429283]
# data_scale_R_t
# [[1.07274303e+01 4.90116159e+00]
#  [4.90116159e+00 5.00699916e+03]]
# patience
# 0
#
#
# Epoch 3
# Averaging Weight with SD
# [0.6144229739037901, 0.05708851605707735]
# [0.3855770260962099, 0.05708851605707735]
# Weight Norms
# [14.543738393912163, 0.6827190031392545]
# standardized_scale_R_t
# [0.99335194 0.64297398] 0.014772329973683792
# Train RMSEs, Pearson ,Coverages, and Widths
# [ 0.924003   40.93328365] [0.958413864171127, 0.6996722278224057] [1.        0.9930459] [  5.74314375 126.90214718]
# Test RMSEs, Pearson , Coverages, and Widths
# [ 0.86561466 36.69393491] [0.9670874988861565, 0.6950182578083643] [0.99583333 1.        ] [  5.66810992 126.03621715]
# data_scale_R_t
# [[   8.07916693   11.2399782 ]
#  [  11.2399782  2436.55427588]]
# patience
# 1
#
#
# Epoch 4
# Averaging Weight with SD
# [0.6617102417936328, 0.04759486944598622]
# [0.3382897582063672, 0.04759486944598622]
# Weight Norms
# [14.823773614216101, 0.644205355635247]
# standardized_scale_R_t
# [0.87368836 0.62613413] 0.02871358153906952
# Train RMSEs, Pearson ,Coverages, and Widths
# [ 0.79953038 12.53532609] [0.9833270950336703, 0.986897433192644] [1. 1.] [ 4.10070546 91.71875798]
# Test RMSEs, Pearson , Coverages, and Widths
# [ 0.78396517 11.42159701] [0.9852050051021712, 0.9850740196317846] [1. 1.] [ 4.08750923 91.05756399]
# data_scale_R_t
# [[   5.874594    -32.35972548]
#  [ -32.35972548 2918.99914761]]
# patience
# 0
#
#
# Epoch 5
# Averaging Weight with SD
# [0.6993871773101513, 0.03673985817408678]
# [0.3006128226898487, 0.036739858174086766]
# Weight Norms
# [14.694847361474391, 0.579298830782751]
# standardized_scale_R_t
# [0.91542257 0.60341661] 0.010358095270579477
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.44789393 8.84564667] [0.9937792501484592, 0.9943091191386885] [1. 1.] [ 2.66989614 59.93076396]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.44453996 8.25958753] [0.9942283989685938, 0.9930598377437935] [1. 1.] [ 2.64181161 59.18386097]
# data_scale_R_t
# [[   6.16691357  -42.65516168]
#  [ -42.65516168 2715.31648559]]
# patience
# 0
#
#
# Epoch 6
# Averaging Weight with SD
# [0.6979986446221902, 0.033974309270993056]
# [0.3020013553778099, 0.03397430927099305]
# Weight Norms
# [14.487256261361164, 0.5445232910477196]
# standardized_scale_R_t
# [0.94334717 0.60751844] 0.010162306434567673
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.22000896 5.37719297] [0.9968740047622133, 0.9981163992771771] [1. 1.] [ 1.99935389 41.94489939]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.23900164 5.22615611] [0.9964724326089007, 0.9974561432938679] [1. 1.] [ 1.98468003 42.09276835]
# data_scale_R_t
# [[   7.11989926  -52.8582556 ]
#  [ -52.8582556  2808.43743442]]
# patience
# 0
#
#
# Epoch 7
# Averaging Weight with SD
# [0.6939612530967543, 0.0314075635866907]
# [0.30603874690324573, 0.0314075635866907]
# Weight Norms
# [14.320014148828916, 0.48914905539819636]
# standardized_scale_R_t
# [0.95792999 0.60547561] 0.013258923915972876
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.16536504 3.71802261] [0.9981370774967273, 0.998947527918799] [1. 1.] [ 1.59612234 35.42159302]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.18577722 3.6870733 ] [0.9977275713905117, 0.998505894381287] [1. 1.] [ 1.59578001 35.43532645]
# data_scale_R_t
# [[   7.43089735  -55.18689061]
#  [ -55.18689061 2893.88514115]]
# patience
# 0
#
#
# Epoch 8
# Averaging Weight with SD
# [0.6931992078951806, 0.029956022822339303]
# [0.3068007921048193, 0.029956022822339296]
# Weight Norms
# [14.156930556534615, 0.4646610141948103]
# standardized_scale_R_t
# [0.97250452 0.60076671] 0.013670235120489873
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.14824087 2.47459552] [0.998615064674814, 0.9992001366664651] [1. 1.] [ 1.38370364 29.82907865]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.16934103 2.38934905] [0.9982110554633525, 0.999090624739403] [1. 1.] [ 1.38296808 29.89026442]
# data_scale_R_t
# [[   7.47594321  -57.98057057]
#  [ -57.98057057 3038.5669688 ]]
# patience
# 0
#
#
# Epoch 9
# Averaging Weight with SD
# [0.6917700712878542, 0.02834617329159328]
# [0.3082299287121458, 0.028346173291593283]
# Weight Norms
# [14.011057937359675, 0.44628171622474283]
# standardized_scale_R_t
# [0.97295102 0.59954822] 0.01419090133229789
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.12879179 1.99282324] [0.9988960274421088, 0.9993805231328428] [1. 1.] [ 1.17695389 25.38307918]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.15107828 1.90795473] [0.9985263398111269, 0.9993286249524943] [0.99583333 1.        ] [ 1.18663446 25.29909769]
# data_scale_R_t
# [[   7.39749362  -59.09037963]
#  [ -59.09037963 3128.7102246 ]]
# patience
# 0
#
#
# Epoch 10
# Averaging Weight with SD
# [0.6941583834520789, 0.026378823086058895]
# [0.3058416165479212, 0.026378823086058892]
# Weight Norms
# [13.908957310409605, 0.4270010670261223]
# standardized_scale_R_t
# [0.97667031 0.59946581] 0.01536928840020484
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.11426918 1.94667838] [0.9990915643547754, 0.9994151762818254] [1. 1.] [ 1.06520012 22.10747794]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.13662786 1.75125702] [0.9987540932171532, 0.9994267589757635] [0.99583333 1.        ] [ 1.06078021 22.09456334]
# data_scale_R_t
# [[   7.25530701  -60.36381033]
#  [ -60.36381033 3168.12760852]]
# patience
# 0
#
#
# Epoch 11
# Averaging Weight with SD
# [0.6958167580360303, 0.02557955747654235]
# [0.3041832419639697, 0.025579557476542347]
# Weight Norms
# [13.838642969023352, 0.39877087053124644]
# standardized_scale_R_t
# [0.98303912 0.59808136] 0.014560952219944247
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.10787373 1.89890669] [0.9991946674120123, 0.9994233593392722] [1. 1.] [ 0.91987753 20.01359419]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.12906782 1.73625696] [0.998891970686083, 0.9994143678829986] [0.99583333 1.        ] [ 0.92681284 20.09600605]
# data_scale_R_t
# [[   7.14683335  -57.8691075 ]
#  [ -57.8691075  3131.97962422]]
# patience
# 0
#
#
# Epoch 12
# Averaging Weight with SD
# [0.6962226148520828, 0.025109341252627496]
# [0.30377738514791713, 0.0251093412526275]
# Weight Norms
# [13.76793566894348, 0.3769911383645208]
# standardized_scale_R_t
# [0.98721501 0.59739723] 0.01243394818641358
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.10383638 1.81817132] [0.9992477821961407, 0.9994718180470437] [1. 1.] [ 0.83820377 18.53228967]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.12408449 1.66895801] [0.9989702082797038, 0.9994566903757555] [0.99583333 1.        ] [ 0.84512798 18.47727297]
# data_scale_R_t
# [[   7.16532098  -57.49496255]
#  [ -57.49496255 3134.12701742]]
# patience
# 0
#
#
# Epoch 13
# Averaging Weight with SD
# [0.6980716609217904, 0.024158605629275215]
# [0.30192833907820954, 0.024158605629275208]
# Weight Norms
# [13.700796241882893, 0.35449330946437646]
# standardized_scale_R_t
# [0.9881963  0.59607871] 0.010681529756537411
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.10159389 1.72637857] [0.9992779333918044, 0.9995168035201224] [0.99860918 0.99860918] [ 0.78954285 17.06997712]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.12141715 1.59539921] [0.9990150854746351, 0.9994954947775724] [0.99583333 1.        ] [ 0.79159781 17.09705412]
# data_scale_R_t
# [[   7.19902459  -57.45349998]
#  [ -57.45349998 3107.75220186]]
# patience
# 0
#
#
# Epoch 14
# Averaging Weight with SD
# [0.6989555273725745, 0.0233682191172835]
# [0.30104447262742556, 0.0233682191172835]
# Weight Norms
# [13.647798797837764, 0.3550028140044236]
# standardized_scale_R_t
# [0.98507669 0.59443675] 0.009751528877088775
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.09847906 1.588948  ] [0.999324285157229, 0.9995942308604019] [0.99860918 0.99860918] [ 0.75789873 15.62058933]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.11661217 1.42396579] [0.9990910682564954, 0.9995988261222427] [0.99583333 1.        ] [ 0.76296971 15.67742532]
# data_scale_R_t
# [[   7.15254905  -57.79269049]
#  [ -57.79269049 3106.95852422]]
# patience
# 0
#
#
# Epoch 15
# Averaging Weight with SD
# [0.7001637104916909, 0.022693412286682417]
# [0.2998362895083091, 0.022693412286682414]
# Weight Norms
# [13.606754446374742, 0.35165732514862635]
# standardized_scale_R_t
# [0.98146838 0.59412014] 0.009287684411665435
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.09603816 1.56783074] [0.9993590559231761, 0.999612794283402] [0.99860918 0.99860918] [ 0.71481622 14.31859211]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.11358269 1.37283375] [0.999139120013203, 0.9996317893202444] [0.99583333 1.        ] [ 0.72107138 14.49026785]
# data_scale_R_t
# [[   7.15270344  -57.94054655]
#  [ -57.94054655 3111.06400971]]
# patience
# 0
#
#
# Epoch 16
# Averaging Weight with SD
# [0.7011575330634412, 0.022116892811763846]
# [0.29884246693655875, 0.02211689281176384]
# Weight Norms
# [13.573065624604268, 0.3386117013774433]
# standardized_scale_R_t
# [0.97717828 0.59109563] 0.009030332164123394
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.09469619 1.43769441] [0.9993849789533745, 0.9996772151982427] [0.99582754 0.99721836] [ 0.6657171 13.7958115]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.11109019 1.24332492] [0.9991836206286525, 0.9996974977712336] [0.99583333 1.        ] [ 0.66929734 13.95990936]
# data_scale_R_t
# [[   7.11807678  -58.54563572]
#  [ -58.54563572 3106.61689005]]
# patience
# 0
#
#
# Epoch 17
# Averaging Weight with SD
# [0.7016587075782055, 0.02169423794691947]
# [0.2983412924217944, 0.021694237946919482]
# Weight Norms
# [13.536840272885494, 0.3307843507342639]
# standardized_scale_R_t
# [0.97727733 0.58996417] 0.008842618980545067
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.09269493 1.39791655] [0.999409202669317, 0.9996946938497445] [0.99721836 0.99860918] [ 0.64072377 12.83742173]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.10928355 1.20551083] [0.9992078905617781, 0.9997157004250303] [0.99166667 1.        ] [ 0.64487825 12.94112766]
# data_scale_R_t
# [[   7.15312842  -59.1190233 ]
#  [ -59.1190233  3114.65529243]]
# patience
# 0
#
#
# Epoch 18
# Averaging Weight with SD
# [0.7023206257906538, 0.021331430197400678]
# [0.2976793742093462, 0.021331430197400657]
# Weight Norms
# [13.500590985852979, 0.3223911399210002]
# standardized_scale_R_t
# [0.97689719 0.58759813] 0.008690518408764763
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.09179705 1.37137774] [0.9994240495313449, 0.9997060425699339] [0.99443672 0.99582754] [ 0.62513103 12.05266651]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.10830698 1.18144417] [0.9992249831823206, 0.9997269753484084] [0.99166667 1.        ] [ 0.62742825 12.14927491]
# data_scale_R_t
# [[   7.15489073  -59.11191005]
#  [ -59.11191005 3112.37630753]]
# patience
# 0
#
#
# Epoch 19
# Averaging Weight with SD
# [0.7023260733688104, 0.020509829755380918]
# [0.2976739266311897, 0.02050982975538092]
# Weight Norms
# [13.469183561988395, 0.3188269701431403]
# standardized_scale_R_t
# [0.97802788 0.58667606] 0.008098038650159045
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.09018494 1.33591017] [0.9994392646853499, 0.999719101994292] [0.9930459  0.99582754] [ 0.58029214 11.57893804]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.10610891 1.14998602] [0.9992521051587905, 0.9997416759101285] [0.99166667 1.        ] [ 0.58406849 11.67414367]
# data_scale_R_t
# [[   7.14377153  -59.08441252]
#  [ -59.08441252 3115.84153446]]
# patience
# 0
#
#
# Epoch 20
# Averaging Weight with SD
# [0.7025702891258049, 0.020194963563609877]
# [0.29742971087419506, 0.02019496356360988]
# Weight Norms
# [13.438926189910832, 0.31205596485717046]
# standardized_scale_R_t
# [0.97845693 0.58564366] 0.007217849078000868
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08853759 1.31519888] [0.999456478666767, 0.9997216685391545] [0.99443672 0.99721836] [ 0.56458671 11.13122963]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.10462972 1.12359052] [0.9992703601826564, 0.9997517761837748] [0.99166667 1.        ] [ 0.56787138 11.18279768]
# data_scale_R_t
# [[   7.14239853  -58.78477582]
#  [ -58.78477582 3105.90873987]]
# patience
# 0
#
#
# Epoch 21
# Averaging Weight with SD
# [0.7028097294357627, 0.01984845876190812]
# [0.2971902705642373, 0.01984845876190813]
# Weight Norms
# [13.410688457280223, 0.30942445149486475]
# standardized_scale_R_t
# [0.97732137 0.58504495] 0.006457353543988561
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08716935 1.2998099 ] [0.999475220876135, 0.9997278100132999] [0.99582754 0.99582754] [ 0.53912265 10.51858452]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.10381608 1.10885631] [0.9992834668455731, 0.999758466849898] [0.99166667 1.        ] [ 0.5437789  10.59614635]
# data_scale_R_t
# [[   7.15689011  -59.24196636]
#  [ -59.24196636 3103.85108265]]
# patience
# 0
#
#
# Epoch 22
# Averaging Weight with SD
# [0.7032600844488878, 0.01945282147436753]
# [0.2967399155511124, 0.019452821474367523]
# Weight Norms
# [13.386530854026425, 0.3040870576101542]
# standardized_scale_R_t
# [0.97641972 0.58400954] 0.005783992128922576
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08618586 1.29390515] [0.9994886439322891, 0.9997355806669435] [0.99443672 0.99582754] [ 0.5198476 10.4770847]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.10291841 1.09591107] [0.9992972314749751, 0.9997653576929395] [0.99166667 1.        ] [ 0.52277105 10.48337374]
# data_scale_R_t
# [[   7.16760287  -59.59959328]
#  [ -59.59959328 3111.45173379]]
# patience
# 0
#
#
# Epoch 23
# Averaging Weight with SD
# [0.7036176188002873, 0.019237665980711596]
# [0.29638238119971266, 0.019237665980711607]
# Weight Norms
# [13.371817589482932, 0.29198626541742506]
# standardized_scale_R_t
# [0.9751591  0.58308261] 0.004957989513027227
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08507489 1.26498386] [0.99950204137646, 0.999745625399888] [0.99165508 0.99582754] [ 0.50254132 10.08538732]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.10183098 1.0658555 ] [0.9993120366640449, 0.9997758556593028] [0.99166667 1.        ] [ 0.50143543 10.0991896 ]
# data_scale_R_t
# [[   7.16502312  -59.59912772]
#  [ -59.59912772 3102.88001673]]
# patience
# 0
#
#
# Epoch 24
# Averaging Weight with SD
# [0.7038908764920339, 0.01898144563517519]
# [0.296109123507966, 0.018981445635175193]
# Weight Norms
# [13.355805017930205, 0.29724922900997147]
# standardized_scale_R_t
# [0.97421474 0.5821628 ] 0.003790513135327396
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08422566 1.23293144] [0.9995145118548224, 0.9997563816655395] [0.99165508 0.99582754] [0.48782943 9.84933622]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.10085693 1.02955829] [0.9993276876810702, 0.9997899312235268] [0.99166667 1.        ] [0.49214645 9.97735984]
# data_scale_R_t
# [[   7.18229733  -59.71502677]
#  [ -59.71502677 3096.28206089]]
# patience
# 0
#
#
# Epoch 25
# Averaging Weight with SD
# [0.703927339603637, 0.01869003538322387]
# [0.2960726603963631, 0.018690035383223863]
# Weight Norms
# [13.334661823124698, 0.29414661771418615]
# standardized_scale_R_t
# [0.97408042 0.58184681] 0.0033200517127673795
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08351418 1.21015321] [0.9995237405087933, 0.9997652949737786] [0.98887344 0.99582754] [0.4833326  9.59888617]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09985306 1.00360061] [0.9993413611291866, 0.9998003897245986] [0.99166667 1.        ] [0.48404725 9.66674835]
# data_scale_R_t
# [[   7.18320448  -59.7858676 ]
#  [ -59.7858676  3096.39346785]]
# patience
# 0
#
#
# Epoch 26
# Averaging Weight with SD
# [0.7042577926078608, 0.01860995958141763]
# [0.29574220739213913, 0.018609959581417628]
# Weight Norms
# [13.319618364426038, 0.29255625433083476]
# standardized_scale_R_t
# [0.97391656 0.58180631] 0.002589104601158915
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08255406 1.19425592] [0.9995335789796553, 0.9997690046411409] [0.98887344 0.99582754] [0.4659233  9.03514163]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09890153 0.99935356] [0.9993534658343276, 0.9998027325482033] [0.99166667 1.        ] [0.47084701 9.14120873]
# data_scale_R_t
# [[   7.15313157  -59.72167221]
#  [ -59.72167221 3090.80312823]]
# patience
# 0
#
#
# Epoch 27
# Averaging Weight with SD
# [0.7044570082127325, 0.01818766797864624]
# [0.2955429917872677, 0.018187667978646252]
# Weight Norms
# [13.30684307091549, 0.2948163334481945]
# standardized_scale_R_t
# [0.97496708 0.58097977] 0.0015843961740526712
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08178778 1.1779853 ] [0.9995452239174996, 0.9997754292530177] [0.98887344 0.99582754] [0.45318139 8.52594322]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09753592 0.97731569] [0.9993738666185912, 0.9998125523681094] [0.9875 1.    ] [0.45594839 8.60540846]
# data_scale_R_t
# [[   7.15509741  -59.48884705]
#  [ -59.48884705 3083.96407578]]
# patience
# 0
#
#
# Epoch 28
# Averaging Weight with SD
# [0.7043994524083613, 0.018076250231167146]
# [0.2956005475916387, 0.018076250231167143]
# Weight Norms
# [13.29132025110762, 0.2915739401284889]
# standardized_scale_R_t
# [0.97689341 0.58062348] 0.001196273975770659
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08134198 1.17708627] [0.9995523219730236, 0.9997757173111742] [0.98887344 0.99443672] [0.44515935 8.17159137]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09715258 0.97393514] [0.9993805959200383, 0.9998147245550848] [0.98333333 1.        ] [0.44849546 8.20957126]
# data_scale_R_t
# [[   7.16001283  -59.39264079]
#  [ -59.39264079 3082.48288409]]
# patience
# 0
#
#
# Epoch 29
# Averaging Weight with SD
# [0.7051581526490085, 0.01780603139443873]
# [0.2948418473509915, 0.017806031394438725]
# Weight Norms
# [13.281062158325962, 0.2828172575014563]
# standardized_scale_R_t
# [0.9755181  0.57937063] 0.000539221407122287
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.08087629 1.16997802] [0.999558390201893, 0.9997792145202153] [0.98609179 0.99443672] [0.43114147 8.28560348]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09680697 0.96625064] [0.9993861927335298, 0.9998194991409847] [0.9875 1.    ] [0.43105375 8.35855068]
# data_scale_R_t
# [[   7.13381452  -59.27724372]
#  [ -59.27724372 3080.05750113]]
# patience
# 0
#
#
# Epoch 30
# Averaging Weight with SD
# [0.7057398466186756, 0.017613281255866794]
# [0.29426015338132433, 0.017613281255866798]
# Weight Norms
# [13.270859567274904, 0.280456300907393]
# standardized_scale_R_t
# [0.97465729 0.57883684] -0.0005722083801741644
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07984072 1.15629601] [0.9995667773474515, 0.9997849002785629] [0.98748261 0.99443672] [0.41355523 7.93169758]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09556088 0.95479584] [0.9993990303390031, 0.9998243318697698] [0.99166667 1.        ] [0.41386057 8.0042919 ]
# data_scale_R_t
# [[   7.13209561  -59.42528017]
#  [ -59.42528017 3077.12996379]]
# patience
# 0
#
#
# Epoch 31
# Averaging Weight with SD
# [0.7061066490707404, 0.017141269066043373]
# [0.29389335092925967, 0.017141269066043373]
# Weight Norms
# [13.267085940930826, 0.280978606397603]
# standardized_scale_R_t
# [0.97580887 0.57772523] -0.0016694102660075696
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07949463 1.14884916] [0.9995734920952304, 0.9997891115016634] [0.98470097 0.99443672] [0.40423624 7.97616768]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09517009 0.95348639] [0.9994065755178535, 0.9998270839406742] [0.9875 1.    ] [0.40403311 8.06319449]
# data_scale_R_t
# [[   7.14214519  -59.71046526]
#  [ -59.71046526 3073.64588537]]
# patience
# 0
#
#
# Epoch 32
# Averaging Weight with SD
# [0.7063694772041785, 0.01688975429209748]
# [0.2936305227958214, 0.01688975429209748]
# Weight Norms
# [13.263025076573578, 0.2771750614529732]
# standardized_scale_R_t
# [0.97589362 0.57748166] -0.0017792388318904119
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07917584 1.13102308] [0.999578785938389, 0.9997926693592558] [0.98470097 0.99443672] [0.39032768 7.76035943]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09462388 0.93243009] [0.9994150449306601, 0.99982939408792] [0.98333333 1.        ] [0.39181326 7.85245587]
# data_scale_R_t
# [[   7.14404869  -60.24509942]
#  [ -60.24509942 3085.25193963]]
# patience
# 0
#
#
# Epoch 33
# Averaging Weight with SD
# [0.7063133048307869, 0.016752059806973186]
# [0.29368669516921314, 0.016752059806973182]
# Weight Norms
# [13.253190355136296, 0.2712633277283736]
# standardized_scale_R_t
# [0.97768298 0.57763661] -0.0025409142247170414
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07790366 1.11645196] [0.9995884022857806, 0.9997982952665255] [0.98191933 0.99443672] [0.38056298 7.48831887]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09323505 0.90398805] [0.9994285600844887, 0.9998389377516159] [0.96666667 1.        ] [0.38360788 7.59361845]
# data_scale_R_t
# [[   7.13148438  -59.85783571]
#  [ -59.85783571 3083.9760213 ]]
# patience
# 0
#
#
# Epoch 34
# Averaging Weight with SD
# [0.7065113263605972, 0.0166501291017682]
# [0.29348867363940284, 0.0166501291017682]
# Weight Norms
# [13.245680037812773, 0.26991071200252387]
# standardized_scale_R_t
# [0.97796376 0.57747105] -0.00326601117626573
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07747082 1.11230212] [0.9995937358789134, 0.9998005278555995] [0.98470097 0.99443672] [0.37213474 7.49854386]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09261208 0.89118859] [0.999436974932533, 0.9998449499556111] [0.97916667 1.        ] [0.37379819 7.57945747]
# data_scale_R_t
# [[   7.13584515  -59.74639113]
#  [ -59.74639113 3078.83824049]]
# patience
# 0
#
#
# Epoch 35
# Averaging Weight with SD
# [0.7064072581178225, 0.016547630316856608]
# [0.29359274188217754, 0.016547630316856594]
# Weight Norms
# [13.238864122400177, 0.26689696498815085]
# standardized_scale_R_t
# [0.97889509 0.57716575] -0.0039005038669543937
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07665514 1.10858207] [0.9996001855090136, 0.9998030400422911] [0.98748261 0.99443672] [0.36986301 7.25135438]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09185095 0.87635879] [0.9994442082287387, 0.9998496760744395] [0.99166667 1.        ] [0.37284262 7.26894348]
# data_scale_R_t
# [[   7.14561224  -59.69219448]
#  [ -59.69219448 3077.24945697]]
# patience
# 0
#
#
# Epoch 36
# Averaging Weight with SD
# [0.7065496756248476, 0.016530300657451702]
# [0.29345032437515245, 0.0165303006574517]
# Weight Norms
# [13.234555094730649, 0.26531161548978305]
# standardized_scale_R_t
# [0.98155963 0.57709571] -0.004301101505264217
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07577533 1.10099868] [0.9996071484427383, 0.9998055270310865] [0.98470097 0.99443672] [0.36357156 7.13000122]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.0908022  0.87362369] [0.9994549224855628, 0.9998511160260446] [0.9875 1.    ] [0.36571508 7.16635112]
# data_scale_R_t
# [[   7.13779105  -59.66981837]
#  [ -59.66981837 3076.10511852]]
# patience
# 0
#
#
# Epoch 37
# Averaging Weight with SD
# [0.7063876799743538, 0.016225343746656923]
# [0.2936123200256462, 0.016225343746656927]
# Weight Norms
# [13.22708768110427, 0.25864772075327735]
# standardized_scale_R_t
# [0.98169979 0.57635977] -0.004374780687176335
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07557021 1.09602692] [0.9996110785981561, 0.9998073728015837] [0.98609179 0.99443672] [0.35741355 7.05996659]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09043832 0.86391743] [0.999461203076782, 0.9998549070459102] [0.98333333 1.        ] [0.36028561 7.15511696]
# data_scale_R_t
# [[   7.13045689  -59.6141116 ]
#  [ -59.6141116  3075.28059886]]
# patience
# 0
#
#
# Epoch 38
# Averaging Weight with SD
# [0.7065265273911523, 0.015913444223200447]
# [0.2934734726088477, 0.015913444223200453]
# Weight Norms
# [13.224600264257269, 0.2580030601235792]
# standardized_scale_R_t
# [0.9822835  0.57597262] -0.00507592286663637
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07496216 1.09193158] [0.9996151206619842, 0.9998093896242212] [0.98470097 0.99443672] [0.34842994 6.90359553]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08994842 0.84948317] [0.9994647702809247, 0.9998604029375799] [0.98333333 1.        ] [0.35341813 6.97155427]
# data_scale_R_t
# [[   7.14228899  -59.5664766 ]
#  [ -59.5664766  3073.41008175]]
# patience
# 0
#
#
# Epoch 39
# Averaging Weight with SD
# [0.7067307529866133, 0.015512680787969673]
# [0.29326924701338664, 0.015512680787969664]
# Weight Norms
# [13.222606129780152, 0.2582737133114991]
# standardized_scale_R_t
# [0.98262641 0.57526192] -0.005483298731190465
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07493092 1.0836649 ] [0.9996153492853973, 0.9998122574599814] [0.98052851 0.99443672] [0.34345428 6.83769784]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.09002896 0.84276355] [0.9994637614475708, 0.999862736295495] [0.97083333 1.        ] [0.34814422 6.88548897]
# data_scale_R_t
# [[   7.13972145  -59.73752899]
#  [ -59.73752899 3073.36324679]]
# patience
# 0
#
#
# Epoch 40
# Averaging Weight with SD
# [0.706766988304778, 0.015361731565729973]
# [0.2932330116952219, 0.015361731565729965]
# Weight Norms
# [13.221210317859873, 0.2574446953938037]
# standardized_scale_R_t
# [0.98245694 0.5747563 ] -0.005740636799316631
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07452286 1.08254706] [0.9996185226452177, 0.9998133541026241] [0.98191933 0.99443672] [0.33978562 6.73221483]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08954233 0.83891433] [0.9994687651984475, 0.9998657520654683] [0.97916667 1.        ] [0.34298748 6.83148702]
# data_scale_R_t
# [[   7.13341882  -59.62319414]
#  [ -59.62319414 3071.57200574]]
# patience
# 0
#
#
# Epoch 41
# Averaging Weight with SD
# [0.7069057767135466, 0.015329218283406934]
# [0.2930942232864534, 0.015329218283406932]
# Weight Norms
# [13.217655170012337, 0.25344367294731257]
# standardized_scale_R_t
# [0.98287161 0.57463619] -0.006059295187454553
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07394849 1.0757955 ] [0.9996246311182705, 0.9998146567552041] [0.97774687 0.99443672] [0.33578567 6.70378901]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08864546 0.82409698] [0.9994796246574752, 0.9998697940407024] [0.9875 1.    ] [0.34201899 6.82674776]
# data_scale_R_t
# [[   7.12730949  -59.53066839]
#  [ -59.53066839 3074.92444673]]
# patience
# 0
#
#
# Epoch 42
# Averaging Weight with SD
# [0.7069467475114384, 0.015335004830979528]
# [0.2930532524885617, 0.015335004830979533]
# Weight Norms
# [13.213221015040224, 0.25569012754904297]
# standardized_scale_R_t
# [0.98341526 0.57481363] -0.0062961123908228354
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07369329 1.06339476] [0.9996281724975369, 0.9998174006837263] [0.97635605 0.99443672] [0.32966603 6.61187451]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08799688 0.80634758] [0.9994883063430853, 0.9998735304335165] [0.9875 1.    ] [0.33386038 6.66796695]
# data_scale_R_t
# [[   7.11816385  -59.5350773 ]
#  [ -59.5350773  3080.1263878 ]]
# patience
# 0
#
#
# Epoch 43
# Averaging Weight with SD
# [0.7069078994918387, 0.015120314453236599]
# [0.29309210050816126, 0.015120314453236593]
# Weight Norms
# [13.21014654565575, 0.2537615117883082]
# standardized_scale_R_t
# [0.98419378 0.57397578] -0.006461754007233363
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07310184 1.05524666] [0.9996312086054374, 0.9998200293298805] [0.97357441 0.99443672] [0.32364541 6.39738677]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08749855 0.80206534] [0.9994913435877079, 0.999874586094653] [0.975 1.   ] [0.32774213 6.46415124]
# data_scale_R_t
# [[   7.13030586  -59.69304292]
#  [ -59.69304292 3080.61039747]]
# patience
# 0
#
#
# Epoch 44
# Averaging Weight with SD
# [0.7067719533681347, 0.015064220988776232]
# [0.2932280466318653, 0.01506422098877623]
# Weight Norms
# [13.202338296530943, 0.2477433431661168]
# standardized_scale_R_t
# [0.98520666 0.57403142] -0.006272070933381547
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.0727937  1.05173872] [0.9996337838091071, 0.9998207012816861] [0.97496523 0.99443672] [0.31574209 6.27669383]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08709042 0.79178652] [0.9994955000690575, 0.9998767781387258] [0.975 1.   ] [0.322248  6.3548192]
# data_scale_R_t
# [[   7.12824728  -59.54707769]
#  [ -59.54707769 3083.86145412]]
# patience
# 0
#
#
# Epoch 45
# Averaging Weight with SD
# [0.7067322374953059, 0.014981075051712204]
# [0.29326776250469405, 0.014981075051712204]
# Weight Norms
# [13.198262355433927, 0.2431938220914649]
# standardized_scale_R_t
# [0.98586083 0.57371954] -0.006409640057548733
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07236405 1.04273389] [0.9996374302852582, 0.9998235893338366] [0.97774687 0.99443672] [0.31191092 6.10127698]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08661891 0.77928745] [0.9995003319066798, 0.9998802404592544] [0.975 1.   ] [0.31718197 6.19166156]
# data_scale_R_t
# [[   7.13616013  -59.64123481]
#  [ -59.64123481 3085.58380484]]
# patience
# 0
#
#
# Epoch 46
# Averaging Weight with SD
# [0.7065774545991208, 0.014747431695350704]
# [0.2934225454008792, 0.014747431695350697]
# Weight Norms
# [13.194375138344762, 0.24009216299068098]
# standardized_scale_R_t
# [0.98641262 0.57355821] -0.006438809767585972
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07209788 1.0439313 ] [0.999640548113916, 0.999823161445379] [0.97079277 0.99443672] [0.30819193 6.10575085]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08632504 0.77702616] [0.9995041369834803, 0.9998808426836683] [0.98333333 1.        ] [0.30988261 6.17149904]
# data_scale_R_t
# [[   7.13376151  -59.58876321]
#  [ -59.58876321 3086.32130071]]
# patience
# 1
#
#
# Epoch 47
# Averaging Weight with SD
# [0.7062563101183802, 0.014755398036642706]
# [0.29374368988161986, 0.014755398036642704]
# Weight Norms
# [13.193962794959122, 0.23934365379683645]
# standardized_scale_R_t
# [0.98731725 0.57331286] -0.006230867783112336
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07177158 1.03127325] [0.9996425658918026, 0.9998274128289095] [0.97357441 0.99443672] [0.3027678  5.97988222]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08587889 0.77160349] [0.9995083204097831, 0.9998825279549591] [0.97083333 1.        ] [0.3047157  6.07968017]
# data_scale_R_t
# [[   7.13198677  -59.66996351]
#  [ -59.66996351 3087.15973908]]
# patience
# 0
#
#
# Epoch 48
# Averaging Weight with SD
# [0.7062096967681171, 0.01455682140385936]
# [0.2937903032318829, 0.014556821403859352]
# Weight Norms
# [13.192653438231817, 0.2390463556651813]
# standardized_scale_R_t
# [0.9883525 0.572708 ] -0.006259290960783718
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07145465 1.02845058] [0.9996453021471104, 0.9998284259297423] [0.97218359 0.99443672] [0.29745811 5.97553456]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08555398 0.76848243] [0.9995118293761004, 0.9998833083371486] [0.97083333 1.        ] [0.30010126 6.06242782]
# data_scale_R_t
# [[   7.13500681  -59.6952372 ]
#  [ -59.6952372  3084.68319095]]
# patience
# 0
#
#
# Epoch 49
# Averaging Weight with SD
# [0.7061108823736286, 0.014453156699877926]
# [0.2938891176263714, 0.014453156699877921]
# Weight Norms
# [13.191217441774121, 0.23926094693099298]
# standardized_scale_R_t
# [0.98856504 0.57271171] -0.00633774345232312
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07114506 1.02726599] [0.9996477500188385, 0.9998294995000334] [0.97218359 0.99443672] [0.29451866 5.82462438]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08522485 0.76153334] [0.9995150969801267, 0.9998860378413912] [0.97083333 1.        ] [0.29625685 5.90854067]
# data_scale_R_t
# [[   7.13929396  -59.59383197]
#  [ -59.59383197 3079.41368096]]
# patience
# 0
#
#
# Epoch 50
# Averaging Weight with SD
# [0.7060023886613987, 0.014510401262649455]
# [0.2939976113386013, 0.014510401262649464]
# Weight Norms
# [13.187724884854424, 0.23694475716470212]
# standardized_scale_R_t
# [0.98834045 0.57221558] -0.006519670327289009
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07087995 1.02294613] [0.9996506922552291, 0.9998310219445531] [0.97079277 0.99443672] [0.29148673 5.7571992 ]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08491399 0.75625637] [0.9995190337024784, 0.9998877720050985] [0.9625 1.    ] [0.29422284 5.81876467]
# data_scale_R_t
# [[   7.13524595  -59.52709717]
#  [ -59.52709717 3078.94276736]]
# patience
# 0
#
#
# Epoch 51
# Averaging Weight with SD
# [0.7058807768133937, 0.014429536753114208]
# [0.2941192231866063, 0.014429536753114201]
# Weight Norms
# [13.187247806728918, 0.23228380759479847]
# standardized_scale_R_t
# [0.98997046 0.5718998 ] -0.006707279391776165
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07066024 1.0158888 ] [0.9996533350249113, 0.999832950034257] [0.96940195 0.99443672] [0.28827922 5.6375661 ]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.0845719  0.74603568] [0.9995234638900217, 0.9998900178512314] [0.97083333 1.        ] [0.29051152 5.72493463]
# data_scale_R_t
# [[   7.12917444  -59.49045796]
#  [ -59.49045796 3081.76295069]]
# patience
# 0
#
#
# Epoch 52
# Averaging Weight with SD
# [0.7057499602261426, 0.014438144828433024]
# [0.2942500397738574, 0.01443814482843303]
# Weight Norms
# [13.184883680476162, 0.230746927916817]
# standardized_scale_R_t
# [0.99056826 0.57132462] -0.006558033647877181
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07042566 1.01109904] [0.999654481871637, 0.9998348061202607] [0.97079277 0.99443672] [0.28265978 5.62076988]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08445975 0.74262409] [0.9995238011480344, 0.9998910528181696] [0.9625 1.    ] [0.2842651  5.69637692]
# data_scale_R_t
# [[   7.13585051  -59.69178269]
#  [ -59.69178269 3081.8684172 ]]
# patience
# 0
#
#
# Epoch 53
# Averaging Weight with SD
# [0.7055072102850037, 0.014245329126246951]
# [0.2944927897149964, 0.014245329126246948]
# Weight Norms
# [13.184092061257692, 0.22647704708543406]
# standardized_scale_R_t
# [0.9912618  0.57076289] -0.006417566428440142
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07024326 1.00757612] [0.9996557044453525, 0.999836077160727] [0.96662031 0.99443672] [0.27945589 5.61779079]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08433255 0.73867703] [0.9995246922379318, 0.9998922141405503] [0.95833333 1.        ] [0.2815665  5.69863213]
# data_scale_R_t
# [[   7.14401963  -59.79477093]
#  [ -59.79477093 3082.84777388]]
# patience
# 0
#
#
# Epoch 54
# Averaging Weight with SD
# [0.705155064914233, 0.014155399184733042]
# [0.2948449350857671, 0.014155399184733033]
# Weight Norms
# [13.178136258524953, 0.22306277077798978]
# standardized_scale_R_t
# [0.99087333 0.57027109] -0.0062443550800437364
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.07006866 1.00275345] [0.9996572223760835, 0.9998381417843422] [0.97079277 0.9930459 ] [0.2757654  5.48040133]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.0842164  0.73100038] [0.9995259175650293, 0.9998945729645953] [0.95833333 0.99583333] [0.2771238  5.55615269]
# data_scale_R_t
# [[   7.14504283  -59.96420114]
#  [ -59.96420114 3085.58308124]]
# patience
# 0
#
#
# Epoch 55
# Averaging Weight with SD
# [0.7049964466319736, 0.014103690276910861]
# [0.2950035533680263, 0.014103690276910864]
# Weight Norms
# [13.175952099810718, 0.22400344708734649]
# standardized_scale_R_t
# [0.99131071 0.57054689] -0.006333698374662125
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06986944 0.99856251] [0.9996590988168967, 0.9998392900646028] [0.96662031 0.9930459 ] [0.27682009 5.3839819 ]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08399395 0.72853808] [0.9995285900591382, 0.9998951925329743] [0.95       0.99583333] [0.27958047 5.46327868]
# data_scale_R_t
# [[   7.14122175  -59.98275262]
#  [ -59.98275262 3084.59299546]]
# patience
# 0
#
#
# Epoch 56
# Averaging Weight with SD
# [0.7048687609532952, 0.013984677778566414]
# [0.29513123904670485, 0.01398467777856641]
# Weight Norms
# [13.175535554696516, 0.2209910861143239]
# standardized_scale_R_t
# [0.99172175 0.57060668] -0.0063895861748976416
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06960992 0.99267176] [0.999661574261981, 0.9998413263962687] [0.97079277 0.9930459 ] [0.27031804 5.36217784]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08374992 0.72154543] [0.9995312626646724, 0.9998972481695388] [0.94583333 0.99583333] [0.27217626 5.45708659]
# data_scale_R_t
# [[   7.14156949  -59.95385173]
#  [ -59.95385173 3088.33807553]]
# patience
# 0
#
#
# Epoch 57
# Averaging Weight with SD
# [0.7046392970471571, 0.013859960011990772]
# [0.29536070295284295, 0.013859960011990767]
# Weight Norms
# [13.173748519726468, 0.2199193404803482]
# standardized_scale_R_t
# [0.99213654 0.57077843] -0.006222668221434877
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.0694369  0.98870334] [0.9996635955310522, 0.9998429939606094] [0.96383866 0.9930459 ] [0.26829624 5.29347016]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08355205 0.71635437] [0.9995340433181651, 0.99989904868439] [0.94583333 0.99583333] [0.27090652 5.40149678]
# data_scale_R_t
# [[   7.13601345  -59.94612089]
#  [ -59.94612089 3088.43067971]]
# patience
# 0
#
#
# Epoch 58
# Averaging Weight with SD
# [0.7044735219136908, 0.013635897982173215]
# [0.2955264780863092, 0.013635897982173219]
# Weight Norms
# [13.171737060479543, 0.21824069632283402]
# standardized_scale_R_t
# [0.99251664 0.57065441] -0.006299885580054357
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.0692893  0.98568724] [0.9996645504607661, 0.9998444782654946] [0.96662031 0.99443672] [0.26782898 5.21017545]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08352242 0.70994159] [0.9995338102416236, 0.9999015910555447] [0.94166667 0.99583333] [0.27053699 5.29718723]
# data_scale_R_t
# [[   7.1426058   -59.90776761]
#  [ -59.90776761 3089.22539144]]
# patience
# 0
#
#
# Epoch 59
# Averaging Weight with SD
# [0.7043412331113698, 0.013506352888444128]
# [0.2956587668886302, 0.013506352888444133]
# Weight Norms
# [13.165466388782075, 0.21551219286963563]
# standardized_scale_R_t
# [0.99289076 0.57079881] -0.006449564960011397
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06917393 0.98127067] [0.9996663797287636, 0.9998455297640626] [0.96383866 0.9930459 ] [0.26651445 5.18505829]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08326516 0.70415102] [0.9995376473212952, 0.9999028941144544] [0.94583333 0.99583333] [0.26861889 5.24724704]
# data_scale_R_t
# [[   7.13285637  -59.80101238]
#  [ -59.80101238 3088.40266635]]
# patience
# 0
#
#
# Epoch 60
# Averaging Weight with SD
# [0.7043276081586982, 0.01342642389949362]
# [0.29567239184130184, 0.013426423899493629]
# Weight Norms
# [13.159899841957905, 0.21608318190981526]
# standardized_scale_R_t
# [0.99340102 0.570712  ] -0.00646903301557242
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06896237 0.97724659] [0.9996683163679272, 0.9998463331325754] [0.96801113 0.9930459 ] [0.26055034 5.18633469]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.0830605  0.69510449] [0.9995398586499986, 0.9999050450568604] [0.94166667 0.99583333] [0.26357467 5.25050293]
# data_scale_R_t
# [[   7.13366674  -59.78967618]
#  [ -59.78967618 3089.66526741]]
# patience
# 0
#
#
# Epoch 61
# Averaging Weight with SD
# [0.7042335225612495, 0.013301350212682736]
# [0.29576647743875045, 0.01330135021268273]
# Weight Norms
# [13.155928425024568, 0.21399662633506575]
# standardized_scale_R_t
# [0.9941865 0.5699501] -0.006256833322605881
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06881786 0.97771659] [0.9996695442599006, 0.999847199831358] [0.96244784 0.9930459 ] [0.25734571 5.12745184]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08296056 0.69722519] [0.9995408004034136, 0.9999052498175222] [0.925 1.   ] [0.26039657 5.18152111]
# data_scale_R_t
# [[   7.13519274  -59.90805704]
#  [ -59.90805704 3094.2382941 ]]
# patience
# 1
#
#
# Epoch 62
# Averaging Weight with SD
# [0.7042141638435325, 0.013290188444429253]
# [0.2957858361564675, 0.013290188444429259]
# Weight Norms
# [13.152148289685824, 0.21427407661463654]
# standardized_scale_R_t
# [0.99464414 0.56995744] -0.0064264506496108055
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06866697 0.97222157] [0.9996712211332369, 0.9998480359926972] [0.9596662 0.9930459] [0.25313923 5.10067632]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08276789 0.6874834 ] [0.99954320565656, 0.9999071376165244] [0.95       0.99583333] [0.25850238 5.18729249]
# data_scale_R_t
# [[   7.13292444  -59.8477499 ]
#  [ -59.8477499  3091.55309446]]
# patience
# 0
#
#
# Epoch 63
# Averaging Weight with SD
# [0.7040920570672451, 0.013205029007503906]
# [0.2959079429327549, 0.013205029007503906]
# Weight Norms
# [13.146539904693654, 0.21159877265985827]
# standardized_scale_R_t
# [0.9944055 0.5697455] -0.00634149851658398
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06855685 0.97013729] [0.9996722635905664, 0.9998483468279847] [0.96244784 0.9930459 ] [0.25317871 5.01739315]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08276343 0.68090142] [0.9995432374338656, 0.9999087676959937] [0.94583333 0.99583333] [0.25736482 5.10457726]
# data_scale_R_t
# [[   7.13315383  -59.81909625]
#  [ -59.81909625 3089.97785678]]
# patience
# 0
#
#
# Epoch 64
# Averaging Weight with SD
# [0.7041124225436984, 0.013123897546402264]
# [0.2958875774563017, 0.013123897546402271]
# Weight Norms
# [13.143794711035474, 0.21112703376886421]
# standardized_scale_R_t
# [0.99514894 0.5694561 ] -0.006235753856884136
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06843099 0.96520344] [0.9996744887985435, 0.9998495650632733] [0.9596662 0.9930459] [0.25069906 5.01511591]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08261741 0.67398431] [0.9995461100999983, 0.999910392248675] [0.95       0.99583333] [0.25663878 5.09317994]
# data_scale_R_t
# [[   7.1250588   -59.73547504]
#  [ -59.73547504 3089.1211863 ]]
# patience
# 0
#
#
# Epoch 65
# Averaging Weight with SD
# [0.7040206054983791, 0.013100814952014338]
# [0.29597939450162103, 0.013100814952014336]
# Weight Norms
# [13.140556214953897, 0.20989188292246963]
# standardized_scale_R_t
# [0.9954158  0.56907884] -0.006327735423550235
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.0682535  0.96110822] [0.9996757384037366, 0.9998503496722237] [0.95549374 0.9930459 ] [0.24635794 4.93112179]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08248682 0.66781588] [0.9995470077768034, 0.9999116792941571] [0.95       0.99583333] [0.25177541 5.00773574]
# data_scale_R_t
# [[   7.12836027  -59.7291718 ]
#  [ -59.7291718  3088.0822414 ]]
# patience
# 0
#
#
# Epoch 66
# Averaging Weight with SD
# [0.7040098455090897, 0.013093641927697242]
# [0.29599015449091026, 0.01309364192769725]
# Weight Norms
# [13.139919668281905, 0.20804149028495003]
# standardized_scale_R_t
# [0.99599707 0.56928391] -0.006243308484354442
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06808538 0.95877252] [0.9996772885365923, 0.999851404487286] [0.95827538 0.9930459 ] [0.24401344 4.83031563]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08228349 0.66651695] [0.9995491118314339, 0.9999121806744687] [0.9375     0.99583333] [0.2482572  4.90755241]
# data_scale_R_t
# [[   7.12967536  -59.77309287]
#  [ -59.77309287 3089.6714184 ]]
# patience
# 0
#
#
# Epoch 67
# Averaging Weight with SD
# [0.7038176577776057, 0.013075397467927399]
# [0.29618234222239415, 0.013075397467927396]
# Weight Norms
# [13.136958239104548, 0.20886619795984954]
# standardized_scale_R_t
# [0.99605083 0.56916984] -0.006217342664120024
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.0679927  0.95686844] [0.9996784526997402, 0.9998521449477252] [0.95549374 0.9930459 ] [0.2427756  4.77904654]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08226095 0.66232854] [0.9995497608161134, 0.9999134347408895] [0.92083333 0.99583333] [0.24672557 4.83950452]
# data_scale_R_t
# [[   7.12746003  -59.76555919]
#  [ -59.76555919 3090.32825604]]
# patience
# 0
#
#
# Epoch 68
# Averaging Weight with SD
# [0.703634287501733, 0.013071031499321581]
# [0.29636571249826693, 0.013071031499321581]
# Weight Norms
# [13.13257832917956, 0.2102347415579296]
# standardized_scale_R_t
# [0.99568812 0.56920871] -0.006092522709670114
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06773815 0.95441276] [0.999680530253239, 0.999853026319877] [0.9527121 0.9930459] [0.24110853 4.72165336]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.0820393  0.65965054] [0.9995517168552973, 0.9999142610874567] [0.925      0.99583333] [0.24457767 4.76900451]
# data_scale_R_t
# [[   7.12987827  -59.73961089]
#  [ -59.73961089 3088.29659822]]
# patience
# 0
#
#
# Epoch 69
# Averaging Weight with SD
# [0.7035790293621313, 0.012984279508935131]
# [0.2964209706378686, 0.012984279508935137]
# Weight Norms
# [13.131650702242887, 0.20898189793468228]
# standardized_scale_R_t
# [0.99568052 0.56915272] -0.006110921286197562
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06759106 0.9537955 ] [0.9996815904621003, 0.9998535206969892] [0.95132128 0.9930459 ] [0.23791324 4.77921585]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.0818459  0.65776183] [0.9995535155297843, 0.9999150598951315] [0.9125     0.99583333] [0.24136236 4.82940668]
# data_scale_R_t
# [[   7.13326473  -59.72793141]
#  [ -59.72793141 3088.56140234]]
# patience
# 0
#
#
# Epoch 70
# Averaging Weight with SD
# [0.7035657931058298, 0.012959045358924316]
# [0.29643420689417016, 0.012959045358924306]
# Weight Norms
# [13.129440380217373, 0.20784429646575847]
# standardized_scale_R_t
# [0.99578999 0.56907506] -0.006083955162184796
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06749404 0.95105536] [0.9996826029325049, 0.9998541773342058] [0.9527121 0.9930459] [0.23674702 4.76915268]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08171427 0.65174457] [0.9995550468352822, 0.9999164661772862] [0.925      0.99583333] [0.24126855 4.82924867]
# data_scale_R_t
# [[   7.13139118  -59.69838177]
#  [ -59.69838177 3087.9826847 ]]
# patience
# 0
#
#
# Epoch 71
# Averaging Weight with SD
# [0.7033237355295128, 0.01292610991785106]
# [0.29667626447048734, 0.012926109917851059]
# Weight Norms
# [13.127494197129398, 0.20654463955796962]
# standardized_scale_R_t
# [0.99569557 0.56917661] -0.005950444202075816
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06740283 0.94766437] [0.9996838157281825, 0.999855107273806] [0.945758  0.9930459] [0.23521561 4.7054023 ]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.0816146  0.64928965] [0.9995566348945408, 0.9999170893829038] [0.92916667 0.99583333] [0.24013887 4.7684913 ]
# data_scale_R_t
# [[   7.1281035   -59.68898552]
#  [ -59.68898552 3086.25220817]]
# patience
# 0
#
#
# Epoch 72
# Averaging Weight with SD
# [0.703172849302483, 0.012892992390746162]
# [0.2968271506975169, 0.012892992390746165]
# Weight Norms
# [13.126930326655712, 0.2052933493878479]
# standardized_scale_R_t
# [0.99612048 0.56900242] -0.0059271721581488955
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06728406 0.94511064] [0.9996848018849694, 0.9998560101447279] [0.94853964 0.9930459 ] [0.23407349 4.7192233 ]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08138511 0.64749544] [0.9995588956034627, 0.9999177355522599] [0.90833333 0.99583333] [0.23827582 4.79020341]
# data_scale_R_t
# [[   7.12923349  -59.6399872 ]
#  [ -59.6399872  3084.57038909]]
# patience
# 0
#
#
# Epoch 73
# Averaging Weight with SD
# [0.7032192942859367, 0.012907001082698292]
# [0.29678070571406345, 0.01290700108269829]
# Weight Norms
# [13.12556401008228, 0.2037821283817826]
# standardized_scale_R_t
# [0.99654855 0.56885383] -0.006256080552524721
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06708377 0.94593401] [0.9996860189190493, 0.9998557408456316] [0.94714882 0.9930459 ] [0.23260574 4.68153631]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08117216 0.64652929] [0.9995603870126637, 0.9999179461600174] [0.9125     0.99583333] [0.2363622  4.74455905]
# data_scale_R_t
# [[   7.13516632  -59.65970975]
#  [ -59.65970975 3085.69102291]]
# patience
# 1
#
#
# Epoch 74
# Averaging Weight with SD
# [0.7032216642112729, 0.012823507639448454]
# [0.2967783357887272, 0.012823507639448447]
# Weight Norms
# [13.123922287501424, 0.2023207709019225]
# standardized_scale_R_t
# [0.99675795 0.5688538 ] -0.006283485329446918
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06694015 0.94578777] [0.9996873103901751, 0.9998561385541026] [0.94714882 0.9930459 ] [0.23074973 4.606641  ]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.08101691 0.65119273] [0.999561986649039, 0.9999169845146239] [0.92083333 0.99583333] [0.2346688  4.67927198]
# data_scale_R_t
# [[   7.1367339   -59.69026521]
#  [ -59.69026521 3087.12338642]]
# patience
# 2
#
#
# Epoch 75
# Averaging Weight with SD
# [0.7030901025516553, 0.012814168696872751]
# [0.29690989744834473, 0.012814168696872744]
# Weight Norms
# [13.121558356200547, 0.20125212444323395]
# standardized_scale_R_t
# [0.99708847 0.56861047] -0.006238990622354841
# Train RMSEs, Pearson ,Coverages, and Widths
# ...
# [1.01223154 0.56885583] -0.007684778789569844
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06201718 0.88781983] [0.9997308962260582, 0.9998739806528253] [0.9123783  0.99165508] [0.16582445 3.14240393]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07599862 0.57497761] [0.9996139625830643, 0.9999364619742139] [0.87083333 0.99583333] [0.1681113  3.18367865]
# data_scale_R_t
# [[   7.14835983  -59.81909924]
#  [ -59.81909924 3095.62040509]]
# patience
# 0
#
#
# Epoch 138
# Averaging Weight with SD
# [0.7018100545904389, 0.010448231464853231]
# [0.2981899454095611, 0.01044823146485323]
# Weight Norms
# [13.112991458795394, 0.15988447768479955]
# standardized_scale_R_t
# [1.01213388 0.56914086] -0.00776001091452391
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06196248 0.88725931] [0.9997314228678804, 0.9998742548368459] [0.9123783  0.99165508] [0.16484159 3.13297598]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07585013 0.57369547] [0.9996155375209421, 0.9999368738275697] [0.86666667 0.99583333] [0.16801473 3.17108357]
# data_scale_R_t
# [[   7.14685122  -59.79820167]
#  [ -59.79820167 3096.19508742]]
# patience
# 0
#
#
# Epoch 139
# Averaging Weight with SD
# [0.701758204413419, 0.01050418719358443]
# [0.298241795586581, 0.010504187193584433]
# Weight Norms
# [13.112242123225636, 0.16048543065551926]
# standardized_scale_R_t
# [1.01224888 0.56948075] -0.007696437012257501
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06192962 0.88565999] [0.9997316990008489, 0.9998746615277442] [0.90959666 0.9930459 ] [0.16373652 3.11573173]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07582253 0.57050889] [0.9996157872566016, 0.9999375491413302] [0.86666667 0.99583333] [0.16652829 3.15383025]
# data_scale_R_t
# [[   7.1471743   -59.7992489 ]
#  [ -59.7992489  3096.05223922]]
# patience
# 0
#
#
# Epoch 140
# Averaging Weight with SD
# [0.7016630662865158, 0.010517620897502652]
# [0.29833693371348413, 0.010517620897502654]
# Weight Norms
# [13.113163129137392, 0.1592442359122481]
# standardized_scale_R_t
# [1.01233941 0.56980889] -0.00758197693932273
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06188115 0.88541814] [0.9997321009125382, 0.9998747822814334] [0.90820584 0.9930459 ] [0.16289856 3.12308568]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07578155 0.57164483] [0.999616107828442, 0.999937322348498] [0.87083333 0.99583333] [0.16677723 3.15108914]
# data_scale_R_t
# [[   7.1482017   -59.83671132]
#  [ -59.83671132 3096.57654742]]
# patience
# 0
#
#
# Epoch 141
# Averaging Weight with SD
# [0.7016274983832452, 0.010486616942725005]
# [0.29837250161675477, 0.01048661694272501]
# Weight Norms
# [13.112744106324074, 0.15868699372562076]
# standardized_scale_R_t
# [1.01232119 0.56989687] -0.007689531866073659
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06183344 0.88435667] [0.9997325033939727, 0.9998749579334794] [0.90959666 0.9930459 ] [0.162493   3.11460966]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07579407 0.56881601] [0.999615917349568, 0.9999378620322056] [0.85833333 0.99583333] [0.16523181 3.14870793]
# data_scale_R_t
# [[   7.1491297   -59.83816399]
#  [ -59.83816399 3096.24588325]]
# patience
# 0
#
#
# Epoch 142
# Averaging Weight with SD
# [0.7015694657722489, 0.010480481184077897]
# [0.29843053422775107, 0.010480481184077893]
# Weight Norms
# [13.11294754802621, 0.1590312486369491]
# standardized_scale_R_t
# [1.01246043 0.57025553] -0.00768772045032598
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06179721 0.8839454 ] [0.9997328667394068, 0.9998753140530663] [0.90681502 0.9930459 ] [0.16218514 3.12973766]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07572068 0.57031098] [0.999616699184551, 0.9999377991060269] [0.8625     0.99583333] [0.1647459 3.1594067]
# data_scale_R_t
# [[   7.14834844  -59.84499676]
#  [ -59.84499676 3096.89350103]]
# patience
# 1
#
#
# Epoch 143
# Averaging Weight with SD
# [0.7015227038892922, 0.010436081522525693]
# [0.2984772961107078, 0.010436081522525691]
# Weight Norms
# [13.112510155761868, 0.1578035383161105]
# standardized_scale_R_t
# [1.01263755 0.57033478] -0.007693596306448493
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06177114 0.88402964] [0.9997331087310494, 0.9998754906342344] [0.90264256 0.99165508] [0.16203823 3.09799541]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07571892 0.56957398] [0.9996167300172438, 0.9999382365137474] [0.8625     0.99583333] [0.16429031 3.13326788]
# data_scale_R_t
# [[   7.14830024  -59.84640976]
#  [ -59.84640976 3097.40929689]]
# patience
# 2
#
#
# Epoch 144
# Averaging Weight with SD
# [0.7015273028676263, 0.010464944102346939]
# [0.2984726971323736, 0.010464944102346945]
# Weight Norms
# [13.111691091603953, 0.1567385874995822]
# standardized_scale_R_t
# [1.01287106 0.57026659] -0.007722963492957439
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06171816 0.88353587] [0.9997336134522528, 0.999875471839992] [0.8984701 0.9930459] [0.16029066 3.08257399]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07568827 0.56806463] [0.9996171556182493, 0.9999384085865763] [0.86666667 0.99583333] [0.16228301 3.11572865]
# data_scale_R_t
# [[   7.14666358  -59.81840902]
#  [ -59.81840902 3096.85651409]]
# patience
# 3
#
#
# Epoch 145
# Averaging Weight with SD
# [0.7014253297587164, 0.010437186020512279]
# [0.29857467024128354, 0.010437186020512275]
# Weight Norms
# [13.111345869005143, 0.15651032200731907]
# standardized_scale_R_t
# [1.01325904 0.57027887] -0.007686690167360049
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.0616781  0.88340082] [0.9997339408363008, 0.9998756352098441] [0.90264256 0.99165508] [0.16023095 3.09607516]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07568432 0.56869734] [0.9996171954289138, 0.9999383956850753] [0.85833333 0.99583333] [0.16228982 3.13511933]
# data_scale_R_t
# [[   7.14693082  -59.84036953]
#  [ -59.84036953 3097.25556758]]
# patience
# 4
#
#
# Epoch 146
# Averaging Weight with SD
# [0.7013716899321845, 0.010359243303822136]
# [0.29862831006781554, 0.010359243303822145]
# Weight Norms
# [13.111389406424529, 0.1556385419465575]
# standardized_scale_R_t
# [1.01330355 0.57045965] -0.007671406230323598
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06166114 0.88219671] [0.9997342384096173, 0.9998758527735566] [0.89986092 0.9930459 ] [0.15870595 3.04809378]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07565781 0.56686158] [0.9996177100107224, 0.9999386702203592] [0.85833333 0.99583333] [0.16023186 3.08115045]
# data_scale_R_t
# [[   7.14415801  -59.82767727]
#  [ -59.82767727 3096.96406603]]
# patience
# 5
#
#
# Epoch 147
# Averaging Weight with SD
# [0.7013860321487627, 0.010334460787737204]
# [0.2986139678512373, 0.010334460787737199]
# Weight Norms
# [13.111711624835863, 0.1560253763765345]
# standardized_scale_R_t
# [1.0136672  0.57046871] -0.007717636421639397
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06158997 0.88235183] [0.9997348643233674, 0.9998758362397504] [0.9054242 0.9930459] [0.15739412 3.03800044]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07558052 0.56876873] [0.999618505837091, 0.9999382493248106] [0.85416667 0.99583333] [0.15922621 3.07723397]
# data_scale_R_t
# [[   7.14391531  -59.84142186]
#  [ -59.84142186 3096.97538649]]
# patience
# 6
#
#
# Epoch 148
# Averaging Weight with SD
# [0.7014065991170981, 0.010348833775679463]
# [0.2985934008829018, 0.010348833775679476]
# Weight Norms
# [13.11208972524023, 0.1551103176379137]
# standardized_scale_R_t
# [1.01381479 0.57045313] -0.007727980798300705
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.0615772  0.88275531] [0.999735098824022, 0.9998759378498254] [0.89429764 0.9930459 ] [0.15564196 3.03064703]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07557942 0.57056553] [0.9996186606328008, 0.9999381165596016] [0.85       0.99583333] [0.15845554 3.06747609]
# data_scale_R_t
# [[   7.1425009   -59.85225207]
#  [ -59.85225207 3097.59557631]]
# patience
# 7
#
#
# Epoch 149
# Averaging Weight with SD
# [0.7013954424161554, 0.010305704501138338]
# [0.2986045575838446, 0.01030570450113834]
# Weight Norms
# [13.113370904694584, 0.15523518620615745]
# standardized_scale_R_t
# [1.01410349 0.57076018] -0.007816129997327564
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06152853 0.88112253] [0.9997355789410229, 0.9998760918995938] [0.89012517 0.9930459 ] [0.15567515 3.03269622]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07555504 0.56785029] [0.9996189512505707, 0.9999384199064393] [0.86666667 0.99583333] [0.15847248 3.07019238]
# data_scale_R_t
# [[   7.14208574  -59.8232131 ]
#  [ -59.8232131  3096.71992715]]
# patience
# 8
#
#
# Epoch 150
# Averaging Weight with SD
# [0.7014683212835463, 0.010262392587018575]
# [0.29853167871645353, 0.01026239258701857]
# Weight Norms
# [13.113046815589597, 0.15542733480212417]
# standardized_scale_R_t
# [1.01437688 0.57093064] -0.007913139484732639
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06149922 0.88105877] [0.99973592195873, 0.999876284074748] [0.89707928 0.9930459 ] [0.15525036 3.01748405]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.0754753 0.5679276] [0.9996198105165337, 0.9999386571034534] [0.86666667 0.99583333] [0.15772924 3.06967535]
# data_scale_R_t
# [[   7.14182005  -59.8043322 ]
#  [ -59.8043322  3096.82448665]]
# patience
# 9
#
#
# Epoch 151
# Averaging Weight with SD
# [0.7014525563457079, 0.010282717597421729]
# [0.29854744365429203, 0.010282717597421723]
# Weight Norms
# [13.112284065272043, 0.15384705500914955]
# standardized_scale_R_t
# [1.01448883 0.57099617] -0.00798342832293159
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.0614492  0.88172911] [0.9997362734137789, 0.9998764390498921] [0.89012517 0.9930459 ] [0.15485097 3.03209102]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07544981 0.56852135] [0.9996200389728875, 0.9999389479497706] [0.8625     0.99583333] [0.15759544 3.08108708]
# data_scale_R_t
# [[   7.14203043  -59.8188847 ]
#  [ -59.8188847  3097.66931992]]
# patience
# 10
#
#
# Epoch 152
# Averaging Weight with SD
# [0.7014651780970758, 0.01033997108172998]
# [0.29853482190292424, 0.010339971081729979]
# Weight Norms
# [13.113631356306167, 0.15463678844552534]
# standardized_scale_R_t
# [1.01483335 0.57120021] -0.007933721194491898
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06139219 0.88179791] [0.999736757648638, 0.9998766872085887] [0.89290682 0.99026426] [0.15426428 3.0184477 ]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07537373 0.56911635] [0.9996208361669756, 0.9999390974794087] [0.85       0.99583333] [0.15692152 3.05936352]
# data_scale_R_t
# [[   7.1417422   -59.83808574]
#  [ -59.83808574 3098.4865561 ]]
# patience
# 11
#
#
# Epoch 153
# Averaging Weight with SD
# [0.7014503108558997, 0.01026014565422026]
# [0.2985496891441003, 0.010260145654220263]
# Weight Norms
# [13.112900599226691, 0.15389150830714363]
# standardized_scale_R_t
# [1.01526285 0.57123112] -0.007917150034412013
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06135051 0.88079582] [0.999737073699695, 0.9998767609134775] [0.89012517 0.9930459 ] [0.15318481 2.97797696]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07535745 0.56666909] [0.9996209269242305, 0.9999394278541927] [0.85416667 0.99583333] [0.15547671 3.00879765]
# data_scale_R_t
# [[   7.14238219  -59.82821999]
#  [ -59.82821999 3098.09379582]]
# patience
# 12
#
#
# Epoch 154
# Averaging Weight with SD
# [0.7014379652787788, 0.010293247601618406]
# [0.2985620347212212, 0.010293247601618411]
# Weight Norms
# [13.114473099942883, 0.15377941611494284]
# standardized_scale_R_t
# [1.0150241  0.57118896] -0.007872013837724262
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06131106 0.88227997] [0.9997375114246011, 0.9998768961225603] [0.89151599 0.99165508] [0.15278634 2.94744021]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07531682 0.56937215] [0.9996214338020659, 0.9999394680634347] [0.85833333 0.99166667] [0.15482204 2.984139  ]
# data_scale_R_t
# [[   7.14163631  -59.84177142]
#  [ -59.84177142 3099.28483673]]
# patience
# 13
#
#
# Epoch 155
# Averaging Weight with SD
# [0.7014226744431307, 0.010275688852725881]
# [0.29857732555686933, 0.010275688852725876]
# Weight Norms
# [13.115173343945504, 0.15265048974722267]
# standardized_scale_R_t
# [1.01541869 0.57133678] -0.007895361668066049
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06125633 0.88149911] [0.9997379468670704, 0.999877105140518] [0.88456189 0.9930459 ] [0.15254994 2.94168062]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07524639 0.56723436] [0.9996220628189796, 0.9999399467286278] [0.85       0.99166667] [0.15468992 2.97903478]
# data_scale_R_t
# [[   7.14259428  -59.82598074]
#  [ -59.82598074 3099.09147725]]
# patience
# 14
#
#
# Epoch 156
# Averaging Weight with SD
# [0.7014194115752653, 0.010248398674593994]
# [0.2985805884247348, 0.010248398674594001]
# Weight Norms
# [13.11427356949189, 0.15284844205021025]
# standardized_scale_R_t
# [1.01565634 0.57160539] -0.00789329509998402
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06122245 0.87869001] [0.9997382520122934, 0.9998771805566462] [0.88595271 0.99165508] [0.15176952 2.9207688 ]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07516775 0.56051982] [0.9996227859758049, 0.9999406416467168] [0.85833333 0.99166667] [0.15375476 2.96332683]
# data_scale_R_t
# [[   7.1435801   -59.7858293 ]
#  [ -59.7858293  3097.28424543]]
# patience
# 15
#
#
# Epoch 157
# Averaging Weight with SD
# [0.7014277884897723, 0.010241189591990397]
# [0.2985722115102276, 0.0102411895919904]
# Weight Norms
# [13.115075461177979, 0.15214281828599166]
# standardized_scale_R_t
# [1.01565249 0.57174963] -0.00784504408097642
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06120428 0.87717338] [0.9997385066227866, 0.9998774782783079] [0.88178025 0.99026426] [0.15133018 2.89810023]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07515831 0.55739944] [0.9996230233838868, 0.9999412119485692] [0.8625     0.99166667] [0.15310951 2.95009422]
# data_scale_R_t
# [[   7.14220218  -59.77040126]
#  [ -59.77040126 3096.88536176]]
# patience
# 16
#
#
# Epoch 158
# Averaging Weight with SD
# [0.7014365822294518, 0.010152221498204347]
# [0.298563417770548, 0.01015222149820435]
# Weight Norms
# [13.116753539941358, 0.1512791230711012]
# standardized_scale_R_t
# [1.01577648 0.57190557] -0.007766904514450137
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06117827 0.87644836] [0.9997388187757971, 0.9998776520963948] [0.88317107 0.9930459 ] [0.15043444 2.88981415]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07519834 0.55719689] [0.9996226150460681, 0.9999413085298332] [0.85   0.9875] [0.15248572 2.94322422]
# data_scale_R_t
# [[   7.1428029   -59.784212  ]
#  [ -59.784212   3096.82902779]]
# patience
# 17
#
#
# Epoch 159
# Averaging Weight with SD
# [0.7013674454577532, 0.010069780438723648]
# [0.29863255454224685, 0.010069780438723643]
# Weight Norms
# [13.116990327365057, 0.15042549344019637]
# standardized_scale_R_t
# [1.01601893 0.57215133] -0.007658532379194499
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06118237 0.87455472] [0.999739004236063, 0.99987793115874] [0.87760779 0.99026426] [0.15010269 2.89709007]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07516142 0.55467963] [0.9996232383144074, 0.9999415752883511] [0.84583333 0.9875    ] [0.15160806 2.94963232]
# data_scale_R_t
# [[   7.14081591  -59.77215575]
#  [ -59.77215575 3095.98958313]]
# patience
# 18
#
#
# Epoch 160
# Averaging Weight with SD
# [0.7013501819547144, 0.010058754159799965]
# [0.29864981804528534, 0.010058754159799965]
# Weight Norms
# [13.116948337426157, 0.15015478624247638]
# standardized_scale_R_t
# [1.01612235 0.57216747] -0.007621224756463692
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06113833 0.87456146] [0.9997392631784158, 0.9998781070221955] [0.87621697 0.98748261] [0.14953735 2.86563518]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07514015 0.55478176] [0.9996233434713298, 0.9999417469455496] [0.85   0.9875] [0.15198489 2.91290751]
# data_scale_R_t
# [[   7.14168895  -59.7873186 ]
#  [ -59.7873186  3096.31287702]]
# patience
# 19
#
#
# Epoch 161
# Averaging Weight with SD
# [0.7014059521110815, 0.01001815166115765]
# [0.2985940478889185, 0.010018151661157644]
# Weight Norms
# [13.11777663297659, 0.14979616818616517]
# standardized_scale_R_t
# [1.01644765 0.57214323] -0.0076198878387839925
# Train RMSEs, Pearson ,Coverages, and Widths
# [0.06110487 0.87481911] [0.9997396024951481, 0.9998781848584409] [0.87482615 0.98887344] [0.14871738 2.87973977]
# Test RMSEs, Pearson , Coverages, and Widths
# [0.07505869 0.55528827] [0.9996242678571985, 0.9999417902167633] [0.85416667 0.99583333] [0.15129035 2.93960352]
# data_scale_R_t
# [[   7.14053069  -59.77209752]
#  [ -59.77209752 3096.48411636]]
# patience
# 20

# %%
# value

# %%
G_u_test.shape
# Out:
# (274, 240, 2)

# %%
import random

# %%
random_idx = random.sample(range(y_valid_cur.shape[0]), k = 8)

# %%
fig, axs = plt.subplots(8, 2,figsize=(15, 15))
# axs = axs.ravel()
# counter = 0
for idx, i in enumerate(random_idx):
    # print(counter)
    truth = y_valid_cur[i,:]
    preds = best_G_u_test[:, i,:]
    percts = np.percentile(preds, axis = 0, q = (2.5, 97.5))
    lis = percts[0,:]
    uis = percts[1,:]
    
    
    axs[idx, 0].hist(preds[:,0])
    axs[idx, 0].axvline(truth[0], color='green', linewidth=2)
    axs[idx, 0].axvline(lis[0], color='red', linewidth=2)
    axs[idx, 0].axvline(uis[0], color='red', linewidth=2)
    
    axs[idx, 1].hist(preds[:,1])
    axs[idx, 1].axvline(truth[1], color='green', linewidth=2)
    axs[idx, 1].axvline(lis[1], color='red', linewidth=2)
    axs[idx, 1].axvline(uis[1], color='red', linewidth=2)
    
    # counter+=2
    # print(counter)
    
    # plt.show()
plt.savefig('prediction_intervals.png', bbox_inches='tight')

# %%
plt.scatter(y_valid_cur[:, 0], best_averaged_targets_test[:,0])
plt.axline((0,0), slope = 1, c= "black")
plt.show()
plt.scatter(y_valid_cur[:,1], best_averaged_targets_test[:, 1])
plt.axline((0,0), slope = 1, c= "black")
plt.show()

# %%
plt.plot(w1_catch)
plt.show()

# %%
plt.plot(w1_sd_catch)
plt.show()

# %%
plt.errorbar(range(0, len(w1_catch)), w1_catch, w1_sd_catch)
# Out:
# <ErrorbarContainer object of 3 artists>

# %%
# plt.errorbar(range(0, len(weight_norm_mean)), weight_norm_mean, weight_norm_sd)

# %%
# cov_mat_final, _ = create_cov(smiles_feats_train.shape[0],initial_ensembles)

# %%
# cov_mat_final

# %%
# R_t

# %%
# np.cov(y_chk_full.values.T)

# %%
best_R_t
# Out:
# array([[   7.1491297 ,  -59.83816399],
#        [ -59.83816399, 3096.24588325]])

# %%
np.cov(y_train_cur.T)
# Out:
# array([[   7.15535584,  -59.64784375],
#        [ -59.64784375, 3085.51412811]])

# %%
best_train_metrics
# Out:
# [array([0.06183344, 0.88435667]),
#  array([0.90959666, 0.9930459 ]),
#  array([0.162493  , 3.11460966]),
#  [0.9997325033939727, 0.9998749579334794]]

# %%
best_test_metrics
# Out:
# [array([0.07579407, 0.56881601]),
#  array([0.85833333, 0.99583333]),
#  array([0.16523181, 3.14870793]),
#  [0.999615917349568, 0.9999378620322056]]

# %%
best_mod1_weight
# Out:
# 0.7016274983832452

# %%
best_mod2_weight
# Out:
# 0.29837250161675477

# %%
pickle.dump(w1_catch, open('..//Data//best_w1_catch_applications.pkl', 'wb'))

# %%
pickle.dump(w1_sd_catch, open('..//Data//best_w1_sd_catch_applications.pkl', 'wb'))

# %%
pickle.dump(best_initial_ensembles, open('..//Data//best_initial_ensembles_applications.pkl', 'wb'))

# %%
pickle.dump(G_u_test, open('..//Data//G_u_test_applications.pkl', 'wb'))

# %%
pickle.dump(best_averaged_targets_test, open('..//Data//best_averaged_targets_test_applications.pkl', 'wb'))

# %%
pickle.dump(y_valid_cur, open('..//Data//y_valid_cur_applications.pkl', 'wb'))

# %%
plt.hist(y_train_cur[:,0])
plt.show()

# %%
plt.hist(y_train_cur[:,1])
plt.show()
